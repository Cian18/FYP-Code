# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Input
import matplotlib.pyplot as plt
import numpy as np
plt.style.use(['science', 'notebook', 'grid'])

# %%
#import data
X = np.load("C:\\Users\\Cian\\1 FYP Code\\Code_with_git\\Prototype 3\\Camera Angle\\Training Data\\Data.npy")
y = np.load("C:\\Users\\Cian\\1 FYP Code\\Code_with_git\\Prototype 3\\Camera Angle\\Training Data\\Labels.npy")

#Split into 10 groups
data_folds = np.array_split(X,10)
labels_folds = np.array_split(y,10)

# %% [markdown]
# Perform 10-fold cross validation. To achieve values for the performance on each class.

# %%
acc_0 = []
acc_1 = []
acc_2 = []
for i in range(10):
    X_val = data_folds[i]
    y_val = np.argmax(labels_folds[i],axis=1)
    
    X_train = data_folds[:i]+data_folds[i+1:]
    y_train = labels_folds[:i]+labels_folds[i+1:]
    
    #create the model
    M = Sequential()
    M.add(Input(shape=(66,)))
    M.add(Dense(units=50, activation='tanh'))
    M.add(Dense(units=3, activation='softmax'))

    #train the model
    M.compile(loss='categorical_crossentropy', optimizer='adam', metrics=['accuracy'])
    M.fit(X, y, epochs=50, batch_size=20)
    
    #Make a prediction
    result = np.argmax(M.predict(X_val),axis=1)
    
    #Compare to the labels
    acc_0.append(np.sum(y_val[y_val==0]==result[y_val==0])/len(y_val[y_val==0]))
    acc_1.append(np.sum(y_val[y_val==1]==result[y_val==1])/len(y_val[y_val==1]))
    acc_2.append(np.sum(y_val[y_val==2]==result[y_val==2])/len(y_val[y_val==2]))
# Out:
# Epoch 1/50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 937us/step - accuracy: 0.5185 - loss: 1.0665
# Epoch 2/50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 840us/step - accuracy: 0.9315 - loss: 0.6033
# Epoch 3/50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 948us/step - accuracy: 0.9798 - loss: 0.3390
# Epoch 4/50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 798us/step - accuracy: 0.9680 - loss: 0.2320
# Epoch 5/50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 765us/step - accuracy: 0.9689 - loss: 0.1695
# Epoch 6/50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 864us/step - accuracy: 0.9887 - loss: 0.1208
# Epoch 7/50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 761us/step - accuracy: 0.9926 - loss: 0.0924
# Epoch 8/50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 875us/step - accuracy: 0.9769 - loss: 0.1041
# Epoch 9/50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 814us/step - accuracy: 0.9865 - loss: 0.0841
# Epoch 10/50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 793us/step - accuracy: 0.9917 - loss: 0.0722
# Epoch 11/50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 720us/step - accuracy: 0.9874 - loss: 0.0622
# ...

# %%
np.mean(acc_0),np.mean(acc_1),np.mean(acc_2), np.mean([np.mean(acc_0),np.mean(acc_1),np.mean(acc_2)])
# Out:
# (1.0, 1.0, 1.0, 1.0)
